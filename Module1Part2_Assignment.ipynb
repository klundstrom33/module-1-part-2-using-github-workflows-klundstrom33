# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_stats(data, type, xlabel, ylabel, title):
    if type=='hist':
        sns.histplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    if type=='scatter':
        sns.scatterplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    return()

# %%
data_df=pd.DataFrame([np.random.rand(100), np.random.rand(100)], index=['Random 1', 'Random 2']).T
data_df
# Out:
#     Random 1  Random 2
# 0   0.629738  0.381548
# 1   0.483690  0.456993
# 2   0.048030  0.632110
# 3   0.015484  0.153424
# 4   0.870301  0.714903
# ..       ...       ...
# 95  0.669735  0.144282
# 96  0.660503  0.869065
# 97  0.338582  0.898830
# 98  0.494414  0.349958
# 99  0.547340  0.289219
#
# [100 rows x 2 columns]

# %%
plot_stats(data_df,'scatter', 'Index', 'Random Value', 'Scatterplot')
# Out:
# ()

# %%
plot_stats(data_df,'hist', ' Random Value', 'Count', 'Histogram')
# Out:
# ()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_stats(data, type, xlabel, ylabel, title):
    if type=='hist':
        sns.histplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    if type=='scatter':
        sns.scatterplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    return()

# %%
data_df=pd.DataFrame([np.random.rand(100), np.random.rand(100), np.random.rand(100)], index=['Random 1', 'Random 2', 'Random 3']).T
data_df
# Out:
#     Random 1  Random 2  Random 3
# 0   0.372042  0.778484  0.445352
# 1   0.385218  0.908932  0.047585
# 2   0.927048  0.790314  0.514784
# 3   0.049266  0.028737  0.035912
# 4   0.652797  0.927745  0.823424
# ..       ...       ...       ...
# 95  0.198294  0.799380  0.787561
# 96  0.921155  0.887328  0.958600
# 97  0.564345  0.851236  0.652041
# 98  0.028490  0.961173  0.806874
# 99  0.629578  0.996995  0.452138
#
# [100 rows x 3 columns]

# %%
plot_stats(data_df,'scatter', 'Index', 'Random Value', 'Scatterplot')
# Out:
# ()

# %%
plot_stats(data_df,'hist', ' Random Value', 'Count', 'Histogram')
# Out:
# ()

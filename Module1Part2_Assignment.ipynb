# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_stats(data, type, xlabel, ylabel, title):
    if type=='hist':
        sns.histplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    if type=='scatter':
        plt.scatter(data[0],data[1])
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    return()

# %%
data_df=pd.DataFrame([np.random.rand(100), np.random.rand(100), np.random.rand(100)], index=['Random 1', 'Random 2', 'Random 3']).T
data_df
# Out:
#     Random 1  Random 2  Random 3
# 0   0.041899  0.587099  0.435352
# 1   0.647523  0.656292  0.948193
# 2   0.250148  0.427720  0.892972
# 3   0.326384  0.084100  0.910981
# 4   0.711277  0.358517  0.858488
# ..       ...       ...       ...
# 95  0.276611  0.769083  0.505503
# 96  0.467133  0.239115  0.210225
# 97  0.609023  0.700490  0.436719
# 98  0.682883  0.662342  0.938623
# 99  0.584199  0.915392  0.752540
#
# [100 rows x 3 columns]

# %%
plot_stats([data_df['Random 1'], data_df['Random 2']],'scatter','Random 1', 'Random 2','Scatterplot')
# Out:
# ()

# %%
plot_stats(data_df,'hist', ' Random Value', 'Count', 'Histogram')
# Out:
# ()

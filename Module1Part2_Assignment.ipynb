# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_stats(data, type, xlabel, ylabel, title):
    if type=='hist':
        sns.histplot(data)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    if type=='scatter':
        plt.scatter(data[0],data[1])
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)
    return()

# %%
data_df=pd.DataFrame([np.random.rand(100), np.random.rand(100), np.random.rand(100)], index=['Random 1', 'Random 2', 'Random 3']).T
data_df
# Out:
#     Random 1  Random 2  Random 3
# 0   0.137320  0.479084  0.642072
# 1   0.375210  0.423952  0.175572
# 2   0.895171  0.312103  0.573404
# 3   0.787368  0.143685  0.103723
# 4   0.326225  0.367619  0.000548
# ..       ...       ...       ...
# 95  0.361319  0.136689  0.610330
# 96  0.932632  0.908023  0.493721
# 97  0.051267  0.146837  0.666394
# 98  0.202815  0.074856  0.599528
# 99  0.912067  0.507063  0.839743
#
# [100 rows x 3 columns]

# %%
plot_stats([data_df['Random 1'], data_df['Random 2']],'scatter','Random 1', 'Random 2','Scatterplot')
# Out:
# ()

# %%
plot_stats(data_df,'hist', ' Random Value', 'Count', 'Histogram')
# Out:
# ()
